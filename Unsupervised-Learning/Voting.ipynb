# %%
#voting
from sklearn.ensemble import VotingClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report

# %%
X,y=make_classification(
   n_samples=100,
    n_features=20,
    random_state=42,
    n_redundant=2,
    n_informative=5
  )

# %%
X_train,X_test,y_train,y_test=train_test_split(
 X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

  
lr=LogisticRegression()
svc=SVC()
dtc=DecisionTreeClassifier(max_depth=3)

# %%
vot=VotingClassifier(
    estimators=[
      ("lr",lr),
       ("svc",svc),
         ("dtc",dtc)
  ]
)

# %%
vot.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression()), ('svc', SVC()),
#                              ('dtc', DecisionTreeClassifier(max_depth=3))])

# %%
y_pred=vot.predict(X_test)

print("accuracy",accuracy_score(y_pred,y_test))
# Out:
# accuracy 0.9333333333333333

# %%
from sklearn.datasets import make_regression

# %%
X,y=make_regression(
   n_samples=100,
    n_features=20,
    random_state=42,
    n_informative=5
  )

# %%
X_train,X_test,y_train,y_test=train_test_split(
 X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
linear=LinearRegression()
dsr=DecisionTreeRegressor()
svr=SVR()

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr=VotingRegressor(
    estimators=[
("linear",linear),("dsr",dsr),("svr",svr) ]
)

# %%
vr.fit(X_train,y_train)
# Out:
# VotingRegressor(estimators=[('linear', LinearRegression()),
#                             ('dsr', DecisionTreeRegressor()), ('svr', SVR())])

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
dsc=DecisionTreeClassifier()
svc = SVC(probability=True)

meta_model=LogisticRegression()

sc=StackingClassifier(
    estimators=[("dsc",dsc),("svc",svc)],
    final_estimator=meta_model,
    cv=5
)

# %%
sc.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 sc.fit(X_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = [
#      67     "{}={}".format(name, arg)
#      68     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      69 ]
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_stacking.py:700, in StackingClassifier.fit(self, X, y, sample_weight, **fit_params)
#     665 """Fit the estimators.
#     666
#     667 Parameters
#    (...)
#     697     Returns a fitted instance of estimator.
#     698 """
#     699 _raise_for_params(fit_params, self, "fit")
# --> 700 check_classification_targets(y)
#     701 if type_of_target(y) == "multilabel-indicator":
#     702     self._label_encoder = [LabelEncoder().fit(yk) for yk in y.T]
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\multiclass.py:222, in check_classification_targets(y)
#     214 y_type = type_of_target(y, input_name="y")
#     215 if y_type not in [
#     216     "binary",
#     217     "multiclass",
#    (...)
#     220     "multilabel-sequences",
#     221 ]:
# --> 222     raise ValueError(
#     223         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     224         "classifier, which expects discrete classes on a "
#     225         "regression target with continuous values."
#     226     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
